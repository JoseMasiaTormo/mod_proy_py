# %% [markdown]
# # EDA Notebook

# %% [markdown]
# ## 1. Importar librerías necesarias
# Importar pandas, numpy, matplotlib y seaborn para el análisis y visualización de datos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Cargar el archivo CSV
# Solicitar al usuario la ruta del archivo .csv y cargarlo en un DataFrame de pandas.

# %%
file_path = '../data/processed/clean_sales.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ## 3. Visualizar las primeras filas del dataset
# Mostrar las primeras filas del DataFrame usando head() para obtener una vista general de los datos.

# %%
df.head()
# Out:
#     Brands       Models         Colors  Memory   Storage  Camera  Rating  \
# 0  Samsung  Galaxy M31S   Mirage Black  8192.0  131072.0    True     4.3
# 1    Nokia          3.2          Steel  2048.0   16384.0    True     3.8
# 2   Realme           C2  Diamond Black  2048.0       0.0    True     4.4
# 3  Infinix       Note 5       Ice Blue  4096.0   65536.0    True     4.2
# 4    Apple    Iphone 11          Black  4096.0   65536.0    True     4.6
#
#    Selling Price  Original Price               Mobile  Discount  \
# 0        19330.0         20999.0  SAMSUNG GALAXY M31S    1669.0
# 1        10199.0         10199.0            Nokia 3.2       0.0
# 2         6999.0          7999.0            realme C2    1000.0
# 3        12999.0         12999.0       Infinix Note 5       0.0
# 4        49900.0         49900.0      Apple iPhone 11       0.0
#
#    discount percentage
# 0                 7.95
# 1                 0.00
# 2                12.50
# 3                 0.00
# 4                 0.00

# %% [markdown]
# ## 4. Explorar información general del dataset
# Utilizar info() y shape para mostrar información sobre el número de filas, columnas y tipos de datos.

# %%
df.info()
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 899 entries, 0 to 898
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Brands               899 non-null    str
#  1   Models               899 non-null    str
#  2   Colors               899 non-null    str
#  3   Memory               899 non-null    float64
#  4   Storage              899 non-null    float64
#  5   Camera               899 non-null    bool
#  6   Rating               899 non-null    float64
#  7   Selling Price        899 non-null    float64
#  8   Original Price       899 non-null    float64
#  9   Mobile               899 non-null    str
#  10  Discount             899 non-null    float64
#  11  discount percentage  899 non-null    float64
# dtypes: bool(1), float64(7), str(4)
# memory usage: 78.3 KB
# Número de filas: 899
# Número de columnas: 12

# %% [markdown]
# ## 5. Describir variables numéricas y categóricas
# Usar describe() para variables numéricas y value_counts() para variables categóricas.

# %%
# Numerical variables
df.describe()
# Out:
#              Memory        Storage      Rating  Selling Price  Original Price  \
# count    899.000000     899.000000  899.000000     899.000000      899.000000
# mean    3782.641824   70278.190211    4.009900   20026.658509    21785.122358
# std     2781.502523   84792.986953    0.827225   21626.743413    24043.864796
# min        0.000000       0.000000    0.000000    1000.000000     1000.000000
# 25%     2048.000000   16384.000000    4.000000    8000.000000     8990.000000
# 50%     3072.000000   32768.000000    4.200000   12999.000000    14300.000000
# 75%     6144.000000  131072.000000    4.400000   21999.000000    23999.000000
# max    18432.000000  524288.000000    5.000000  169999.000000   189999.000000
#
#            Discount  discount percentage
# count    899.000000           899.000000
# mean    1758.463849             5.695061
# std     5878.552665            11.519138
# min        0.000000             0.000000
# 25%        0.000000             0.000000
# 50%        0.000000             0.000000
# 75%     1202.500000             7.870000
# max    75000.000000            70.610000

# %%
# Categorical values (Example for a columnn)
df['Brands'].value_counts()
# Out:
# Brands
# Samsung         210
# Nokia            77
# Oppo             76
# Lg               63
# Realme           60
# Gionee           58
# Vivo             57
# Lenovo           53
# Xiaomi           49
# Motorola         47
# Infinix          40
# Asus             33
# Htc              29
# Apple            25
# Poco             12
# Google Pixel     10
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Visualizar valores nulos y duplicados
# Identificar y visualizar la cantidad de valores nulos y filas duplicadas en el dataset.

# %%
# Null values
df.isnull().sum()
# Out:
# Brands                 0
# Models                 0
# Colors                 0
# Memory                 0
# Storage                0
# Camera                 0
# Rating                 0
# Selling Price          0
# Original Price         0
# Mobile                 0
# Discount               0
# discount percentage    0
# dtype: int64

# %%
# Duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. Análisis univariado de variables numéricas
# Realizar histogramas y boxplots para analizar la distribución de las variables numéricas.

# %%
# Histogram for a numerical variable
df['Selling Price'].hist()
plt.show()

# Boxplot
df.boxplot(column='Selling Price')
plt.show()

# %% [markdown]
# ## 8. Análisis univariado de variables categóricas
# Realizar gráficos de barras para analizar la frecuencia de las variables categóricas.

# %%
# Bar plot for a categorical variable
df['Brands'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## 9. Análisis bivariado entre variables
# Explorar relaciones entre variables numéricas y categóricas mediante scatterplots y tablas cruzadas.

# %%
# Scatterplot
plt.scatter(df['Selling Price'], df['Rating'])
plt.xlabel('Selling Price')
plt.ylabel('Discount')
plt.show()

# Crosstab for two categorical variables   
pd.crosstab(df['Brands'], df['Storage'])
# Out:
# Storage       0.0       2.0       4.0       8.0       10.0      16.0      \
# Brands
# Apple                0         0         0         0         0         0
# Asus                 0         0         0         0         0         0
# Gionee               0         1         0         0         0         2
# Google Pixel         0         0         0         0         0         0
# Htc                  0         0         0         0         0         0
# Infinix              0         0         0         0         0         0
# Lenovo               0         0         0         0         0         0
# Lg                   0         0         0         0         0         0
# Motorola             0         0         0         0         0         0
# Nokia                7         4        15         2         1         4
# Oppo                 0         0         0         0         0         0
# Poco                 0         0         0         0         0         0
# Realme              10         0         0         0         0         0
# Samsung              3        16         0         0         0         0
# Vivo                 0         0         0         0         0         0
# Xiaomi               0         0         0         0         0         0
#
# Storage       48.0      64.0      100.0     128.0     ...  256.0     512.0     \
# Brands                                                ...
# Apple                0         0         0         0  ...         0         0
# Asus                 0         0         0         0  ...         0         0
# Gionee               0         0         0         1  ...         0         0
# Google Pixel         0         0         0         0  ...         0         0
# Htc                  0         0         0         0  ...         0         0
# Infinix              0         0         0         0  ...         0         0
# Lenovo               0         0         0         0  ...         0         1
# Lg                   0         0         0         0  ...         0         0
# Motorola             0         0         0         0  ...         0         0
# Nokia                1         1         0         4  ...         2         0
# Oppo                 0         0         0         0  ...         0         0
# Poco                 0         0         0         0  ...         0         0
# Realme               0         0         0         0  ...         0         0
# Samsung              0         0         2         1  ...         1         1
# Vivo                 0         0         0         0  ...         0         0
# Xiaomi               0         0         0         0  ...         0         0
#
# Storage       4096.0    8192.0    16384.0   32768.0   65536.0   131072.0  \
# Brands
# Apple                0         0         0         1         8         6
# Asus                 0         4         9         6         4         3
# Gionee               4         7        19        17         7         0
# Google Pixel         0         0         1         1         3         5
# Htc                  3         5        13         4         1         3
# Infinix              0         0         1        14        18         6
# Lenovo               6        10        14        18         4         0
# Lg                   6         8        16         9        13        11
# Motorola             0         2        11         7        17         8
# Nokia                5         2         5         7        13         3
# Oppo                 0         0         9        10        23        24
# Poco                 0         0         0         1         4         7
# Realme               0         0         0         7        19        18
# Samsung             12        26        24        31        27        51
# Vivo                 0         0         3         9        21        16
# Xiaomi               0         0         2        10        20        15
#
# Storage       262144.0  524288.0
# Brands
# Apple                4         6
# Asus                 3         4
# Gionee               0         0
# Google Pixel         0         0
# Htc                  0         0
# Infinix              1         0
# Lenovo               0         0
# Lg                   0         0
# Motorola             2         0
# Nokia                0         0
# Oppo                10         0
# Poco                 0         0
# Realme               6         0
# Samsung             11         3
# Vivo                 8         0
# Xiaomi               2         0
#
# [16 rows x 22 columns]

# %% [markdown]
# ## 10. Visualización de correlaciones
# Calcular y visualizar la matriz de correlación entre variables numéricas usando un heatmap.

# %%
# Correlation matrix
corr = df.select_dtypes(include=('number')).corr()
sns.heatmap(corr, annot=True)
plt.show()
